# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# ### Load Fold data

# %%
adult_dataset = pd.read_csv('./data/adult_dataset.csv')

# %%
adult_dataset.shape
# Out:
# (48842, 15)

# %%
adult_dataset
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# 13      32            Private  205019     Assoc-acdm             12
# 14      40            Private  121772      Assoc-voc             11
# 15      34            Private  245487        7th-8th              4
# 16      25   Self-emp-not-inc  176756        HS-grad              9
# 17      32            Private  186824        HS-grad              9
# 18      38            Private   28887           11th              7
# 19      43   Self-emp-not-inc  292175        Masters             14
# 20      40            Private  193524      Doctorate             16
# 21      54            Private  302146        HS-grad              9
# 22      35        Federal-gov   76845            9th              5
# 23      43            Private  117037           11th              7
# 24      59            Private  109015        HS-grad              9
# 25      56          Local-gov  216851      Bachelors             13
# 26      19            Private  168294        HS-grad              9
# 27      54                  ?  180211   Some-college             10
# 28      39            Private  367260        HS-grad              9
# 29      49            Private  193366        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 48812   81                  ?   26711      Assoc-voc             11
# 48813   60            Private  117909      Assoc-voc             11
# 48814   39            Private  229647      Bachelors             13
# 48815   38            Private  149347        Masters             14
# 48816   43          Local-gov   23157        Masters             14
# 48817   23            Private   93977        HS-grad              9
# 48818   73       Self-emp-inc  159691   Some-college             10
# 48819   35            Private  176967   Some-college             10
# 48820   66            Private  344436        HS-grad              9
# 48821   27            Private  430340   Some-college             10
# 48822   40            Private  202168    Prof-school             15
# 48823   51            Private   82720        HS-grad              9
# 48824   22            Private  269623   Some-college             10
# 48825   64   Self-emp-not-inc  136405        HS-grad              9
# 48826   50          Local-gov  139347        Masters             14
# 48827   55            Private  224655        HS-grad              9
# 48828   38            Private  247547      Assoc-voc             11
# 48829   58            Private  292710     Assoc-acdm             12
# 48830   32            Private  173449        HS-grad              9
# 48831   48            Private  285570        HS-grad              9
# 48832   61            Private   89686        HS-grad              9
# 48833   31            Private  440129        HS-grad              9
# 48834   25            Private  350977        HS-grad              9
# 48835   48          Local-gov  349230        Masters             14
# 48836   33            Private  245211      Bachelors             13
# 48837   39            Private  215419      Bachelors             13
# 48838   64                  ?  321403        HS-grad              9
# 48839   38            Private  374983      Bachelors             13
# 48840   44            Private   83891      Bachelors             13
# 48841   35       Self-emp-inc  182148      Bachelors             13
#
#                marital-status          occupation     relationship  \
# 0               Never-married        Adm-clerical    Not-in-family
# 1          Married-civ-spouse     Exec-managerial          Husband
# 2                    Divorced   Handlers-cleaners    Not-in-family
# 3          Married-civ-spouse   Handlers-cleaners          Husband
# 4          Married-civ-spouse      Prof-specialty             Wife
# 5          Married-civ-spouse     Exec-managerial             Wife
# 6       Married-spouse-absent       Other-service    Not-in-family
# 7          Married-civ-spouse     Exec-managerial          Husband
# 8               Never-married      Prof-specialty    Not-in-family
# 9          Married-civ-spouse     Exec-managerial          Husband
# 10         Married-civ-spouse     Exec-managerial          Husband
# 11         Married-civ-spouse      Prof-specialty          Husband
# 12              Never-married        Adm-clerical        Own-child
# 13              Never-married               Sales    Not-in-family
# 14         Married-civ-spouse        Craft-repair          Husband
# 15         Married-civ-spouse    Transport-moving          Husband
# 16              Never-married     Farming-fishing        Own-child
# 17              Never-married   Machine-op-inspct        Unmarried
# 18         Married-civ-spouse               Sales          Husband
# 19                   Divorced     Exec-managerial        Unmarried
# 20         Married-civ-spouse      Prof-specialty          Husband
# 21                  Separated       Other-service        Unmarried
# 22         Married-civ-spouse     Farming-fishing          Husband
# 23         Married-civ-spouse    Transport-moving          Husband
# 24                   Divorced        Tech-support        Unmarried
# 25         Married-civ-spouse        Tech-support          Husband
# 26              Never-married        Craft-repair        Own-child
# 27         Married-civ-spouse                   ?          Husband
# 28                   Divorced     Exec-managerial    Not-in-family
# 29         Married-civ-spouse        Craft-repair          Husband
# ...                       ...                 ...              ...
# 48812      Married-civ-spouse                   ?          Husband
# 48813      Married-civ-spouse      Prof-specialty          Husband
# 48814           Never-married        Tech-support    Not-in-family
# 48815      Married-civ-spouse      Prof-specialty          Husband
# 48816      Married-civ-spouse     Exec-managerial          Husband
# 48817           Never-married   Machine-op-inspct        Own-child
# 48818                Divorced     Exec-managerial    Not-in-family
# 48819      Married-civ-spouse     Protective-serv          Husband
# 48820                 Widowed               Sales   Other-relative
# 48821           Never-married               Sales    Not-in-family
# 48822      Married-civ-spouse      Prof-specialty          Husband
# 48823      Married-civ-spouse        Craft-repair          Husband
# 48824           Never-married        Craft-repair        Own-child
# 48825                 Widowed     Farming-fishing    Not-in-family
# 48826      Married-civ-spouse      Prof-specialty             Wife
# 48827               Separated     Priv-house-serv    Not-in-family
# 48828           Never-married        Adm-clerical        Unmarried
# 48829                Divorced      Prof-specialty    Not-in-family
# 48830      Married-civ-spouse   Handlers-cleaners          Husband
# 48831      Married-civ-spouse        Adm-clerical          Husband
# 48832      Married-civ-spouse               Sales          Husband
# 48833      Married-civ-spouse        Craft-repair          Husband
# 48834           Never-married       Other-service        Own-child
# 48835                Divorced       Other-service    Not-in-family
# 48836           Never-married      Prof-specialty        Own-child
# 48837                Divorced      Prof-specialty    Not-in-family
# 48838                 Widowed                   ?   Other-relative
# 48839      Married-civ-spouse      Prof-specialty          Husband
# 48840                Divorced        Adm-clerical        Own-child
# 48841      Married-civ-spouse     Exec-managerial          Husband
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    White     Male          2174             0
# 1                    White     Male             0             0
# 2                    White     Male             0             0
# 3                    Black     Male             0             0
# 4                    Black   Female             0             0
# 5                    White   Female             0             0
# 6                    Black   Female             0             0
# 7                    White     Male             0             0
# 8                    White   Female         14084             0
# 9                    White     Male          5178             0
# 10                   Black     Male             0             0
# 11      Asian-Pac-Islander     Male             0             0
# 12                   White   Female             0             0
# 13                   Black     Male             0             0
# 14      Asian-Pac-Islander     Male             0             0
# 15      Amer-Indian-Eskimo     Male             0             0
# 16                   White     Male             0             0
# 17                   White     Male             0             0
# 18                   White     Male             0             0
# 19                   White   Female             0             0
# 20                   White     Male             0             0
# 21                   Black   Female             0             0
# 22                   Black     Male             0             0
# 23                   White     Male             0          2042
# 24                   White   Female             0             0
# 25                   White     Male             0             0
# 26                   White     Male             0             0
# 27      Asian-Pac-Islander     Male             0             0
# 28                   White     Male             0             0
# 29                   White     Male             0             0
# ...                    ...      ...           ...           ...
# 48812                White     Male          2936             0
# 48813                White     Male          7688             0
# 48814                White   Female             0          1669
# 48815                White     Male             0             0
# 48816                White     Male             0          1902
# 48817                White     Male             0             0
# 48818                White   Female             0             0
# 48819                White     Male             0             0
# 48820                White   Female             0             0
# 48821                White   Female             0             0
# 48822                White     Male         15024             0
# 48823                White     Male             0             0
# 48824                White     Male             0             0
# 48825                White     Male             0             0
# 48826                White   Female             0             0
# 48827                White   Female             0             0
# 48828                Black   Female             0             0
# 48829                White     Male             0             0
# 48830                White     Male             0             0
# 48831                White     Male             0             0
# 48832                White     Male             0             0
# 48833                White     Male             0             0
# 48834                White   Female             0             0
# 48835                White     Male             0             0
# 48836                White     Male             0             0
# 48837                White   Female             0             0
# 48838                Black     Male             0             0
# 48839                White     Male             0             0
# 48840   Asian-Pac-Islander     Male          5455             0
# 48841                White     Male             0             0
#
#        hours-per-week  native-country  class
# 0                  40   United-States  <=50K
# 1                  13   United-States  <=50K
# 2                  40   United-States  <=50K
# 3                  40   United-States  <=50K
# 4                  40            Cuba  <=50K
# 5                  40   United-States  <=50K
# 6                  16         Jamaica  <=50K
# 7                  45   United-States   >50K
# 8                  50   United-States   >50K
# 9                  40   United-States   >50K
# 10                 80   United-States   >50K
# 11                 40           India   >50K
# 12                 30   United-States  <=50K
# 13                 50   United-States  <=50K
# 14                 40               ?   >50K
# 15                 45          Mexico  <=50K
# 16                 35   United-States  <=50K
# 17                 40   United-States  <=50K
# 18                 50   United-States  <=50K
# 19                 45   United-States   >50K
# 20                 60   United-States   >50K
# 21                 20   United-States  <=50K
# 22                 40   United-States  <=50K
# 23                 40   United-States  <=50K
# 24                 40   United-States  <=50K
# 25                 40   United-States   >50K
# 26                 40   United-States  <=50K
# 27                 60           South   >50K
# 28                 80   United-States  <=50K
# 29                 40   United-States  <=50K
# ...               ...             ...    ...
# 48812              20   United-States  <=50K
# 48813              40   United-States   >50K
# 48814              40   United-States  <=50K
# 48815              50   United-States   >50K
# 48816              50   United-States   >50K
# 48817              40   United-States  <=50K
# 48818              40   United-States  <=50K
# 48819              40   United-States  <=50K
# 48820               8   United-States  <=50K
# 48821              45   United-States  <=50K
# 48822              55   United-States   >50K
# 48823              40   United-States  <=50K
# 48824              40   United-States  <=50K
# 48825              32   United-States  <=50K
# 48826              40               ?   >50K
# 48827              32   United-States  <=50K
# 48828              40   United-States  <=50K
# 48829              36   United-States  <=50K
# 48830              40   United-States  <=50K
# 48831              40   United-States  <=50K
# 48832              48   United-States  <=50K
# 48833              40   United-States  <=50K
# 48834              40   United-States  <=50K
# 48835              40   United-States  <=50K
# 48836              40   United-States  <=50K
# 48837              36   United-States  <=50K
# 48838              40   United-States  <=50K
# 48839              50   United-States  <=50K
# 48840              40   United-States  <=50K
# 48841              60   United-States   >50K
#
# [48842 rows x 15 columns]

# %%
adult_dataset[(adult_dataset['class'] == '<=50K')].shape
# Out:
# (37155, 15)

# %%
adult_dataset[(adult_dataset['class'] == '>50K')].shape
# Out:
# (11687, 15)

# %% [markdown]
# ## Attribute selection

# %%
pd.crosstab(adult_dataset.age,adult_dataset['class'])
# Out:
# class  <=50K  >50K
# age
# 17       595     0
# 18       862     0
# 19      1050     3
# 20      1112     1
# 21      1090     6
# 22      1161    17
# 23      1307    22
# 24      1162    44
# 25      1119    76
# 26      1068    85
# 27      1117   115
# 28      1101   179
# 29      1025   198
# 30      1031   247
# 31      1050   275
# 32       957   296
# 33      1045   290
# 34       949   354
# 35       997   340
# 36       948   400
# 37       858   422
# 38       850   414
# 39       783   423
# 40       793   394
# 41       808   427
# 42       745   420
# 43       693   411
# 44       659   408
# 45       684   412
# 46       658   439
# ..       ...   ...
# 61       309   141
# 62       290   104
# 63       245    90
# 64       251    89
# 65       214    70
# 66       181    56
# 67       181    57
# 68       141    37
# 69       118    31
# 70       108    25
# 71        90    28
# 72       104    16
# 73        91    17
# 74        59    18
# 75        59    13
# 76        61     8
# 77        46     8
# 78        29     5
# 79        21     9
# 80        34     4
# 81        30     7
# 82        15     0
# 83         9     2
# 84        12     1
# 85         4     1
# 86         1     0
# 87         3     0
# 88         5     1
# 89         2     0
# 90        42    13
#
# [74 rows x 2 columns]

# %% [markdown]
# ### Age can decide the class - Child category is earning less than 50k

# %%
adult_dataset['ageState'] = np.where(adult_dataset['age'] > 22, 'Old', 'Young')

# %%
pd.crosstab(adult_dataset['ageState'] , adult_dataset['class'])
# Out:
# class     <=50K   >50K
# ageState
# Old       31285  11660
# Young      5870     27

# %%
pd.crosstab(adult_dataset.relationship, adult_dataset['class'])
# Out:
# class            <=50K  >50K
# relationship
#  Husband         10870  8846
#  Not-in-family   11307  1276
#  Other-relative   1454    52
#  Own-child        7470   111
#  Unmarried        4816   309
#  Wife             1238  1093

# %%
def checkRelationship(rel):
    if(rel.strip() in ['Husband','Wife']) :
        return 'Family'
    else:
        return 'NonFamily'
adult_dataset['relationshipState'] = adult_dataset['relationship'].apply(checkRelationship)

# %%
pd.crosstab(adult_dataset.relationshipState, adult_dataset['class'])
# Out:
# class              <=50K  >50K
# relationshipState
# Family             12108  9939
# NonFamily          25047  1748

# %%
pd.crosstab(adult_dataset['capital-gain'], adult_dataset['class'])
# Out:
# class         <=50K  >50K
# capital-gain
# 0             35611  9196
# 114               8     0
# 401               5     0
# 594              52     0
# 914              10     0
# 991               6     0
# 1055             37     0
# 1086              8     0
# 1111              1     0
# 1151             13     0
# 1173              5     0
# 1264              2     0
# 1409             10     0
# 1424              4     0
# 1455              4     0
# 1471              9     0
# 1506             24     0
# 1639              1     0
# 1731              1     0
# 1797             10     0
# 1831              9     0
# 1848              9     0
# 2009              3     0
# 2036              5     0
# 2050              5     0
# 2062              3     0
# 2105             15     0
# 2174             74     0
# 2176             31     0
# 2202             28     0
# ...             ...   ...
# 6849             42     0
# 7262              0     1
# 7298              0   364
# 7430              0    15
# 7443              7     0
# 7688              0   410
# 7896              1     3
# 7978              2     0
# 8614              0    82
# 9386              0    31
# 9562              0     5
# 10520             0    64
# 10566             8     0
# 10605             0    19
# 11678             0     4
# 13550             0    42
# 14084             0    49
# 14344             0    34
# 15020             0    10
# 15024             0   513
# 15831             0     8
# 18481             0     2
# 20051             0    49
# 22040             1     0
# 25124             0     6
# 25236             0    14
# 27828             0    58
# 34095             6     0
# 41310             3     0
# 99999             0   244
#
# [123 rows x 2 columns]

# %%
def checkCapitalGain(gain):
    if( gain == 0 ):
        return 'Unknown'
    elif( gain < 7000):
        return 'Low'
    else:
        return 'High'
adult_dataset['capitalGainState'] = adult_dataset['capital-gain'].apply(checkCapitalGain)

# %%
pd.crosstab(adult_dataset['capitalGainState'], adult_dataset['class'])
# Out:
# class             <=50K  >50K
# capitalGainState
# High                 28  2027
# Low                1516   464
# Unknown           35611  9196

# %%
pd.crosstab(adult_dataset['native-country'], adult_dataset['class'])
# Out:
# class                        <=50K   >50K
# native-country
#  ?                             637    220
#  Cambodia                       19      9
#  Canada                        119     63
#  China                          86     36
#  Columbia                       81      4
#  Cuba                          104     34
#  Dominican-Republic             98      5
#  Ecuador                        39      6
#  El-Salvador                   144     11
#  England                        80     47
#  France                         22     16
#  Germany                       148     58
#  Greece                         31     18
#  Guatemala                      85      3
#  Haiti                          66      9
#  Holand-Netherlands              1      0
#  Honduras                       18      2
#  Hong                           22      8
#  Hungary                        13      6
#  India                          89     62
#  Iran                           37     22
#  Ireland                        26     11
#  Italy                          71     34
#  Jamaica                        91     15
#  Japan                          60     32
#  Laos                           21      2
#  Mexico                        904     47
#  Nicaragua                      46      3
#  Outlying-US(Guam-USVI-etc)     22      1
#  Peru                           42      4
#  Philippines                   210     85
#  Poland                         70     17
#  Portugal                       55     12
#  Puerto-Rico                   164     20
#  Scotland                       18      3
#  South                          95     20
#  Taiwan                         39     26
#  Thailand                       25      5
#  Trinadad&Tobago                25      2
#  United-States               33138  10694
#  Vietnam                        79      7
#  Yugoslavia                     15      8

# %%
def checkCountry(ctry):
    if( ctry.strip() == '?' ):
        return 'Unknown'
    elif( ctry.strip() in ['Honduras','Holand-Netherlands','Jamaica','Laos','Dominican-Republic','Vietnam','Columbia','El-Salvador','Guatemala','Haiti','Outlying-US(Guam-USVI-etc)','Puerto-Rico','Mexico']):
        return 'T1'
    else:
        return 'T2'
adult_dataset['geoLoc'] = adult_dataset['native-country'].apply(checkCountry)

# %%
pd.crosstab(adult_dataset['geoLoc'], adult_dataset['class'])
# Out:
# class    <=50K   >50K
# geoLoc
# T1        1774    126
# T2       34744  11341
# Unknown    637    220

# %%
pd.crosstab(adult_dataset['education-num'], adult_dataset['class'])
# Out:
# class          <=50K  >50K
# education-num
# 1                 82     1
# 2                239     8
# 3                482    27
# 4                893    62
# 5                715    41
# 6               1302    87
# 7               1720    92
# 8                609    48
# 9              13281  2503
# 10              8815  2063
# 11              1539   522
# 12              1188   413
# 13              4712  3313
# 14              1198  1459
# 15               217   617
# 16               163   431

# %%
adult_dataset['edState'] = np.where(adult_dataset['education-num'] < 9, 'Low', 'High')

# %%
pd.crosstab(adult_dataset['edState'], adult_dataset['class'])
# Out:
# class    <=50K   >50K
# edState
# High     31113  11321
# Low       6042    366

# %%
pd.crosstab(adult_dataset['marital-status'], adult_dataset['class'])
# Out:
# class                   <=50K  >50K
# marital-status
#  Divorced                5962   671
#  Married-AF-spouse         23    14
#  Married-civ-spouse     12395  9984
#  Married-spouse-absent    570    58
#  Never-married          15384   733
#  Separated               1431    99
#  Widowed                 1390   128

# %%
def checkMarriedState(st):
    if( st.strip() in ['Married-AF-spouse','Married-civ-spouse']):
        return 'M'
    else:
        return 'S'
adult_dataset['maritalStat'] = adult_dataset['marital-status'].apply(checkMarriedState)

# %%
pd.crosstab(adult_dataset['maritalStat'], adult_dataset['class'])
# Out:
# class        <=50K  >50K
# maritalStat
# M            12418  9998
# S            24737  1689

# %%
pd.crosstab(adult_dataset['workclass'], adult_dataset['class'])
# Out:
# class              <=50K  >50K
# workclass
#  ?                  2534   265
#  Federal-gov         871   561
#  Local-gov          2209   927
#  Never-worked         10     0
#  Private           26519  7387
#  Self-emp-inc        757   938
#  Self-emp-not-inc   2785  1077
#  State-gov          1451   530
#  Without-pay          19     2

# %%
pd.crosstab(adult_dataset['race'], adult_dataset['class'])
# Out:
# class                <=50K   >50K
# race
#  Amer-Indian-Eskimo    415     55
#  Asian-Pac-Islander   1110    409
#  Black                4119    566
#  Other                 356     50
#  White               31155  10607

# %%
pd.crosstab(adult_dataset['occupation'], adult_dataset['class'])
# Out:
# class               <=50K  >50K
# occupation
#  ?                   2544   265
#  Adm-clerical        4843   768
#  Armed-Forces          10     5
#  Craft-repair        4729  1383
#  Exec-managerial     3178  2908
#  Farming-fishing     1317   173
#  Handlers-cleaners   1934   138
#  Machine-op-inspct   2650   372
#  Other-service       4719   204
#  Priv-house-serv      239     3
#  Prof-specialty      3388  2784
#  Protective-serv      675   308
#  Sales               4029  1475
#  Tech-support        1026   420
#  Transport-moving    1874   481

# %%
adult_dataset['class-new'] = adult_dataset['class']

# %%
adult_dataset['class'] = np.where(adult_dataset['class-new'] == '<=50K', '0', '1')

# %%
adult_dataset[(adult_dataset['class'] == '0')].shape
# Out:
# (37155, 22)

# %%
adult_dataset[(adult_dataset['class'] == '1')].shape
# Out:
# (11687, 22)

# %%
adult_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 22 columns):
# age                  48842 non-null int64
# workclass            48842 non-null object
# fnlwgt               48842 non-null int64
# education            48842 non-null object
# education-num        48842 non-null int64
# marital-status       48842 non-null object
# occupation           48842 non-null object
# relationship         48842 non-null object
# race                 48842 non-null object
# sex                  48842 non-null object
# capital-gain         48842 non-null int64
# capital-loss         48842 non-null int64
# hours-per-week       48842 non-null int64
# native-country       48842 non-null object
# class                48842 non-null object
# ageState             48842 non-null object
# relationshipState    48842 non-null object
# capitalGainState     48842 non-null object
# geoLoc               48842 non-null object
# edState              48842 non-null object
# maritalStat          48842 non-null object
# class-new            48842 non-null object
# dtypes: int64(6), object(16)
# memory usage: 8.2+ MB

# %% [markdown]
# ### Drop unwanted features and reorder required features

# %%
adult_dataset.drop(['age','workclass','marital-status','race','occupation','fnlwgt','education','education-num','relationship','class-new',
                    'capital-gain','capital-loss','hours-per-week','native-country'],axis=1, inplace=True)

# %%
adult_dataset
# Out:
#            sex class ageState relationshipState capitalGainState   geoLoc  \
# 0         Male     0      Old         NonFamily              Low       T2
# 1         Male     0      Old            Family          Unknown       T2
# 2         Male     0      Old         NonFamily          Unknown       T2
# 3         Male     0      Old            Family          Unknown       T2
# 4       Female     0      Old            Family          Unknown       T2
# 5       Female     0      Old            Family          Unknown       T2
# 6       Female     0      Old         NonFamily          Unknown       T1
# 7         Male     1      Old            Family          Unknown       T2
# 8       Female     1      Old         NonFamily             High       T2
# 9         Male     1      Old            Family              Low       T2
# 10        Male     1      Old            Family          Unknown       T2
# 11        Male     1      Old            Family          Unknown       T2
# 12      Female     0      Old         NonFamily          Unknown       T2
# 13        Male     0      Old         NonFamily          Unknown       T2
# 14        Male     1      Old            Family          Unknown  Unknown
# 15        Male     0      Old            Family          Unknown       T1
# 16        Male     0      Old         NonFamily          Unknown       T2
# 17        Male     0      Old         NonFamily          Unknown       T2
# 18        Male     0      Old            Family          Unknown       T2
# 19      Female     1      Old         NonFamily          Unknown       T2
# 20        Male     1      Old            Family          Unknown       T2
# 21      Female     0      Old         NonFamily          Unknown       T2
# 22        Male     0      Old            Family          Unknown       T2
# 23        Male     0      Old            Family          Unknown       T2
# 24      Female     0      Old         NonFamily          Unknown       T2
# 25        Male     1      Old            Family          Unknown       T2
# 26        Male     0    Young         NonFamily          Unknown       T2
# 27        Male     1      Old            Family          Unknown       T2
# 28        Male     0      Old         NonFamily          Unknown       T2
# 29        Male     0      Old            Family          Unknown       T2
# ...        ...   ...      ...               ...              ...      ...
# 48812     Male     0      Old            Family              Low       T2
# 48813     Male     1      Old            Family             High       T2
# 48814   Female     0      Old         NonFamily          Unknown       T2
# 48815     Male     1      Old            Family          Unknown       T2
# 48816     Male     1      Old            Family          Unknown       T2
# 48817     Male     0      Old         NonFamily          Unknown       T2
# 48818   Female     0      Old         NonFamily          Unknown       T2
# 48819     Male     0      Old            Family          Unknown       T2
# 48820   Female     0      Old         NonFamily          Unknown       T2
# 48821   Female     0      Old         NonFamily          Unknown       T2
# 48822     Male     1      Old            Family             High       T2
# 48823     Male     0      Old            Family          Unknown       T2
# 48824     Male     0    Young         NonFamily          Unknown       T2
# 48825     Male     0      Old         NonFamily          Unknown       T2
# 48826   Female     1      Old            Family          Unknown  Unknown
# 48827   Female     0      Old         NonFamily          Unknown       T2
# 48828   Female     0      Old         NonFamily          Unknown       T2
# 48829     Male     0      Old         NonFamily          Unknown       T2
# 48830     Male     0      Old            Family          Unknown       T2
# 48831     Male     0      Old            Family          Unknown       T2
# 48832     Male     0      Old            Family          Unknown       T2
# 48833     Male     0      Old            Family          Unknown       T2
# 48834   Female     0      Old         NonFamily          Unknown       T2
# 48835     Male     0      Old         NonFamily          Unknown       T2
# 48836     Male     0      Old         NonFamily          Unknown       T2
# 48837   Female     0      Old         NonFamily          Unknown       T2
# 48838     Male     0      Old         NonFamily          Unknown       T2
# 48839     Male     0      Old            Family          Unknown       T2
# 48840     Male     0      Old         NonFamily              Low       T2
# 48841     Male     1      Old            Family          Unknown       T2
#
#       edState maritalStat
# 0        High           S
# 1        High           M
# 2        High           S
# 3         Low           M
# 4        High           M
# 5        High           M
# 6         Low           S
# 7        High           M
# 8        High           S
# 9        High           M
# 10       High           M
# 11       High           M
# 12       High           S
# 13       High           S
# 14       High           M
# 15        Low           M
# 16       High           S
# 17       High           S
# 18        Low           M
# 19       High           S
# 20       High           M
# 21       High           S
# 22        Low           M
# 23        Low           M
# 24       High           S
# 25       High           M
# 26       High           S
# 27       High           M
# 28       High           S
# 29       High           M
# ...       ...         ...
# 48812    High           M
# 48813    High           M
# 48814    High           S
# 48815    High           M
# 48816    High           M
# 48817    High           S
# 48818    High           S
# 48819    High           M
# 48820    High           S
# 48821    High           S
# 48822    High           M
# 48823    High           M
# 48824    High           S
# 48825    High           S
# 48826    High           M
# 48827    High           S
# 48828    High           S
# 48829    High           S
# 48830    High           M
# 48831    High           M
# 48832    High           M
# 48833    High           M
# 48834    High           S
# 48835    High           S
# 48836    High           S
# 48837    High           S
# 48838    High           S
# 48839    High           M
# 48840    High           S
# 48841    High           M
#
# [48842 rows x 8 columns]

# %%
columns = [column for column in adult_dataset.columns if column != 'class']

# %%
columns = columns + ['class']

# %%
adult_dataset = adult_dataset[columns]

# %%
adult_dataset
# Out:
#            sex ageState relationshipState capitalGainState   geoLoc edState  \
# 0         Male      Old         NonFamily              Low       T2    High
# 1         Male      Old            Family          Unknown       T2    High
# 2         Male      Old         NonFamily          Unknown       T2    High
# 3         Male      Old            Family          Unknown       T2     Low
# 4       Female      Old            Family          Unknown       T2    High
# 5       Female      Old            Family          Unknown       T2    High
# 6       Female      Old         NonFamily          Unknown       T1     Low
# 7         Male      Old            Family          Unknown       T2    High
# 8       Female      Old         NonFamily             High       T2    High
# 9         Male      Old            Family              Low       T2    High
# 10        Male      Old            Family          Unknown       T2    High
# 11        Male      Old            Family          Unknown       T2    High
# 12      Female      Old         NonFamily          Unknown       T2    High
# 13        Male      Old         NonFamily          Unknown       T2    High
# 14        Male      Old            Family          Unknown  Unknown    High
# 15        Male      Old            Family          Unknown       T1     Low
# 16        Male      Old         NonFamily          Unknown       T2    High
# 17        Male      Old         NonFamily          Unknown       T2    High
# 18        Male      Old            Family          Unknown       T2     Low
# 19      Female      Old         NonFamily          Unknown       T2    High
# 20        Male      Old            Family          Unknown       T2    High
# 21      Female      Old         NonFamily          Unknown       T2    High
# 22        Male      Old            Family          Unknown       T2     Low
# 23        Male      Old            Family          Unknown       T2     Low
# 24      Female      Old         NonFamily          Unknown       T2    High
# 25        Male      Old            Family          Unknown       T2    High
# 26        Male    Young         NonFamily          Unknown       T2    High
# 27        Male      Old            Family          Unknown       T2    High
# 28        Male      Old         NonFamily          Unknown       T2    High
# 29        Male      Old            Family          Unknown       T2    High
# ...        ...      ...               ...              ...      ...     ...
# 48812     Male      Old            Family              Low       T2    High
# 48813     Male      Old            Family             High       T2    High
# 48814   Female      Old         NonFamily          Unknown       T2    High
# 48815     Male      Old            Family          Unknown       T2    High
# 48816     Male      Old            Family          Unknown       T2    High
# 48817     Male      Old         NonFamily          Unknown       T2    High
# 48818   Female      Old         NonFamily          Unknown       T2    High
# 48819     Male      Old            Family          Unknown       T2    High
# 48820   Female      Old         NonFamily          Unknown       T2    High
# 48821   Female      Old         NonFamily          Unknown       T2    High
# 48822     Male      Old            Family             High       T2    High
# 48823     Male      Old            Family          Unknown       T2    High
# 48824     Male    Young         NonFamily          Unknown       T2    High
# 48825     Male      Old         NonFamily          Unknown       T2    High
# 48826   Female      Old            Family          Unknown  Unknown    High
# 48827   Female      Old         NonFamily          Unknown       T2    High
# 48828   Female      Old         NonFamily          Unknown       T2    High
# 48829     Male      Old         NonFamily          Unknown       T2    High
# 48830     Male      Old            Family          Unknown       T2    High
# 48831     Male      Old            Family          Unknown       T2    High
# 48832     Male      Old            Family          Unknown       T2    High
# 48833     Male      Old            Family          Unknown       T2    High
# 48834   Female      Old         NonFamily          Unknown       T2    High
# 48835     Male      Old         NonFamily          Unknown       T2    High
# 48836     Male      Old         NonFamily          Unknown       T2    High
# 48837   Female      Old         NonFamily          Unknown       T2    High
# 48838     Male      Old         NonFamily          Unknown       T2    High
# 48839     Male      Old            Family          Unknown       T2    High
# 48840     Male      Old         NonFamily              Low       T2    High
# 48841     Male      Old            Family          Unknown       T2    High
#
#       maritalStat class
# 0               S     0
# 1               M     0
# 2               S     0
# 3               M     0
# 4               M     0
# 5               M     0
# 6               S     0
# 7               M     1
# 8               S     1
# 9               M     1
# 10              M     1
# 11              M     1
# 12              S     0
# 13              S     0
# 14              M     1
# 15              M     0
# 16              S     0
# 17              S     0
# 18              M     0
# 19              S     1
# 20              M     1
# 21              S     0
# 22              M     0
# 23              M     0
# 24              S     0
# 25              M     1
# 26              S     0
# 27              M     1
# 28              S     0
# 29              M     0
# ...           ...   ...
# 48812           M     0
# 48813           M     1
# 48814           S     0
# 48815           M     1
# 48816           M     1
# 48817           S     0
# 48818           S     0
# 48819           M     0
# 48820           S     0
# 48821           S     0
# 48822           M     1
# 48823           M     0
# 48824           S     0
# 48825           S     0
# 48826           M     1
# 48827           S     0
# 48828           S     0
# 48829           S     0
# 48830           M     0
# 48831           M     0
# 48832           M     0
# 48833           M     0
# 48834           S     0
# 48835           S     0
# 48836           S     0
# 48837           S     0
# 48838           S     0
# 48839           M     0
# 48840           S     0
# 48841           M     1
#
# [48842 rows x 8 columns]

# %%
adult_dataset[(adult_dataset['class'] == '0')].shape
# Out:
# (37155, 8)

# %%
adult_dataset[(adult_dataset['class'] == '1')].shape
# Out:
# (11687, 8)

# %%
def catToNum(series):
    series = series.astype('category')
    return series.cat.codes

# %%
temp_dataset = adult_dataset[['sex','ageState','relationshipState','capitalGainState','geoLoc','edState','maritalStat']].apply(catToNum)
# 48812            0     0
# 48813            0     1
# 48814            1     0
# 48815            0     1
# 48816            0     1
# 48817            1     0
# 48818            1     0
# 48819            0     0
# 48820            1     0
# 48821            1     0
# 48822            0     1
# 48823            0     0
# 48824            1     0
# 48825            1     0
# 48826            0     1
# 48827            1     0
# 48828            1     0
# 48829            1     0
# 48830            0     0
# 48831            0     0
# 48832            0     0
# 48833            0     0
# 48834            1     0
# 48835            1     0
# 48836            1     0
# 48837            1     0
# 48838            1     0
# 48839            0     0
# 48840            1     0
# 48841            0     1
#
# [48842 rows x 8 columns]

# %%
adult_dataset.to_csv('./data/adult_dataset_preprocessed.csv',index=False)

# %%
def getSample(size, df):
    size1 = int(round(size * 0.50))
    size2 = size - size1
    adult_dataset_less50 = df[(df['class'] == '0')]
    adult_dataset_more50 = df[(df['class'] == '1')]
    adult_sample_less50 = adult_dataset_less50.sample(n=size1)
    adult_sample_more50 = adult_dataset_more50.sample(n=size2)
    return pd.concat((adult_sample_less50, adult_sample_more50))

# %%
adult_ds_300 = getSample(300, adult_dataset)

# %%
adult_ds_300.to_csv('./data/adult_ds300_preprocessed.csv',index=False)

# %%
adult_ds_300.head()
# Out:
#        sex  ageState  relationshipState  capitalGainState  geoLoc  edState  \
# 9878     1         0                  0                 2       1        0
# 22114    1         0                  0                 2       1        0
# 38528    0         0                  1                 2       1        0
# 29258    1         0                  1                 2       1        0
# 41183    1         0                  1                 2       1        0
#
#        maritalStat class
# 9878             0     0
# 22114            0     0
# 38528            1     0
# 29258            1     0
# 41183            1     0

# %%
X = adult_ds_300[adult_ds_300.columns[0:7]]

# %%
y = adult_ds_300['class']

# %%
sss = StratifiedShuffleSplit(n_splits=5, test_size=120, random_state=0)

# %%
i = 1 
for  train_index, test_index in sss.split(X, Y):
    print( i, "TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = adult_ds_300.iloc[train_index], adult_ds_300.iloc[test_index]
    X_train.to_csv("./data/fold/fold" + str(i) + "_train.csv",index=False)
    X_test.to_csv("./data/fold/fold" + str(i) + "_test.csv",index=False)
    i = i + 1
# Out:
# 1 TRAIN: [ 27  90 287 135 156  60 185 166 153 203  94  20 155 150 220 288 290 243
#  197 138  33 238 244 154  49  66 240  80 276 123 257 149   4 277 218 107
#  233  62 200  51  86 190 134 298 122 178 215 143 170  95 194  41 296  59
#  101 144 183 209 136  30   5  15 262 139 282  56 168  14  93  43  55 202
#   37 116  71 231 261  16   3 113 229 284 179  76 226  45  52 181  13 237
#  145  50 225 157 281   2 137  46 207 159   7  10 263  63 236 201 239  18
#   69  19 204 250  83 294 242  40  61 227 212 241 110  92 247  74 161   0
#   89  73  44 274 280 189  24  97 152  75 283 111  64 199 291  54 224 187
#   26 176 265 126 104 125  96 297 112 169  22   8 279 124 255 109  98 230
#  196 267 118 130 106 162 253 158 108 146 214 141  12 206 129 268 272 160] TEST: [ 77 114  57  35 198 147  88 140  65  47 251 192   9  39 245  29 260 164
#   23 264  32 254  81 269  17 292 208 270 128 115   6  99 121  38  42 132
    predictions = clf.predict(fold_test[["sex","ageState","relationshipState","capitalGainState","geoLoc","edState","maritalStat"]])
    tn, fp, fn, tp = confusion_matrix(fold_test['class'], predictions).ravel()
    print("Accuracy -",round(accuracy_score(fold_test['class'], predictions),2))
    print("Recall -",round(recall_score(fold_test['class'], predictions),2))
    print("Precision -",round(precision_score(fold_test['class'], predictions),2))
    print("F1 -",round(f1_score(fold_test['class'], predictions),2)) 
    print("Sensitivity -",round(tp/(tp+fn),2))
    print("Specificity -",round(tn/(tn+fp),2))

# %%
testModel('./data/fold/fold1_train.csv', './data/fold/fold1_test.csv', 'fold1-gini.dot','gini')
# Out:
# Accuracy - 0.8
# Recall - 0.81
# Precision - 0.81
# F1 - 0.81
# Sensitivity - 0.81
# Specificity - 0.79

# %%
testModel('./data/fold/fold1_train.csv', './data/fold/fold1_test.csv', 'fold1-entropy.dot','entropy')
# Out:
# Accuracy - 0.8
# Recall - 0.81
# Precision - 0.81
# F1 - 0.81
# Sensitivity - 0.81
# Specificity - 0.79

# %%
testModel('./data/fold/fold2_train.csv', './data/fold/fold2_test.csv', 'fold2-gini.dot','gini')
# Out:
# Accuracy - 0.85
# Recall - 0.87
# Precision - 0.84
# F1 - 0.85
# Sensitivity - 0.87
# Specificity - 0.83

# %%
testModel('./data/fold/fold2_train.csv', './data/fold/fold2_test.csv', 'fold2-entropy.dot','entropy')
# Out:
# Accuracy - 0.87
# Recall - 0.9
# Precision - 0.84
# F1 - 0.87
# Sensitivity - 0.9
# Specificity - 0.83

# %%
testModel('./data/fold/fold3_train.csv', './data/fold/fold3_test.csv', 'fold3-gini.dot','gini')
# Out:
# Accuracy - 0.78
# Recall - 0.86
# Precision - 0.73
# F1 - 0.79
# Sensitivity - 0.86
# Specificity - 0.72

# %%
testModel('./data/fold/fold3_train.csv', './data/fold/fold3_test.csv', 'fold3-entropy.dot','entropy')
# Out:
# Accuracy - 0.78
# Recall - 0.86
# Precision - 0.73
# F1 - 0.79
# Sensitivity - 0.86
# Specificity - 0.72

# %%
testModel('./data/fold/fold4_train.csv', './data/fold/fold4_test.csv', 'fold4-gini.dot','gini')
# Out:
# Accuracy - 0.78
# Recall - 0.81
# Precision - 0.75
# F1 - 0.78
# Sensitivity - 0.81
# Specificity - 0.74

# %%
testModel('./data/fold/fold4_train.csv', './data/fold/fold4_test.csv', 'fold4-entropy.dot','entropy')
# Out:
# Accuracy - 0.78
# Recall - 0.81
# Precision - 0.75
# F1 - 0.78
# Sensitivity - 0.81
# Specificity - 0.74

# %%
testModel('./data/fold/fold5_train.csv', './data/fold/fold5_test.csv', 'fold5-gini.dot','gini')
# Out:
# Accuracy - 0.82
# Recall - 0.83
# Precision - 0.81
# F1 - 0.82
# Sensitivity - 0.83
# Specificity - 0.8

# %%
testModel('./data/fold/fold5_train.csv', './data/fold/fold5_test.csv', 'fold5-entropy.dot','entropy')
# Out:
# Accuracy - 0.81
# Recall - 0.82
# Precision - 0.8
# F1 - 0.81
# Sensitivity - 0.82
# Specificity - 0.8
